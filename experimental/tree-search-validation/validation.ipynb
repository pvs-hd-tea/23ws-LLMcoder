# %%
from llmcoder import LLMCoder

# %%
llmcoder = LLMCoder(
    analyzers=["mypy_analyzer_v1", "signature_analyzer_v1", "gpt_score_analyzer_v1"],
    max_iter=5,
    feedback_variant="coworker",
    n_procs=4)

# %%
initial_code = '''from langchain.document_loaders import DirectoryLoader, JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embed and store
from langchain.vectorstores.elasticsearch import ElasticsearchStore 
from langchain.embeddings import GPT4AllEmbeddings
from langchain.embeddings import OllamaEmbeddings # We can also try Ollama embeddings

from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

import os
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import time

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# pip install jq
schema = {
    'jq_schema': '.text'
}

es = get_es_connection()

REINDEX = False

# pip install gpt4all
# Needs Ubuntu > 22.04 because of glibc

if REINDEX:
    # Clear the index
    es.indices.delete(index="eurlex-langchain", ignore=[400, 404])

    start_time = time.time()
    vectorstore = '''

# %%
completion = llmcoder.complete(initial_code, n=3)
# Out:
# [LLMcoder] Creating first completions...
# [LLMcoder] Choosing conversation R with score 0
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp5ueqhjs8.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp5ueqhjs8.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp5ueqhjs8.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmp5ueqhjs8.py:39: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmp5ueqhjs8.py:42: error: Unexpected keyword argument "device" for "OllamaEmbeddings"  [call-arg]
# [Mypy] /tmp/tmp5ueqhjs8.py:43: error: Unexpected keyword argument "device" for "GPT4AllEmbeddings"  [call-arg]
# [Mypy] /tmp/tmp5ueqhjs8.py:47: error: Missing positional arguments "file_path", "jq_schema" in call to "JSONLoader"  [call-arg]
# [Mypy] /tmp/tmp5ueqhjs8.py:51: error: Argument 1 to "CallbackManager" has incompatible type "StreamingStdOutCallbackHandler"; expected "list[BaseCallbackHandler]"  [arg-type]
# [Mypy] /tmp/tmp5ueqhjs8.py:54: error: Too many arguments for "load" of "JSONLoader"  [call-arg]
# [Mypy] /tmp/tmp5ueqhjs8.py:55: error: Argument 1 to "loads" has incompatible type "list[Document]"; expected "str | bytes | bytearray"  [arg-type]
# [Mypy] /tmp/tmp5ueqhjs8.py:63: error: "RecursiveCharacterTextSplitter" has no attribute "split"  [attr-defined]
# [Mypy] /tmp/tmp5ueqhjs8.py:69: error: "ElasticsearchStore" has no attribute "add"  [attr-defined]
# [Mypy] /tmp/tmp5ueqhjs8.py:76: error: "ElasticsearchStore" has no attribute "add"  [attr-defined]
# [Mypy] Found 13 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: OllamaEmbeddings
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] Found problematic function or class: CallbackManager
# [Signatures] Found problematic function or class: load
# [Signatures] Found problematic function or class: JSONLoader.load
# [Signatures] Found problematic function or class: loads
# [Signatures] Found problematic function or class: RecursiveCharacterTextSplitter
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'GPT4AllEmbeddings', None), ('langchain', 'RecursiveCharacterTextSplitter', None), ('langchain', 'CallbackManager', None), ('langchain', 'OllamaEmbeddings', None), ('langchain', 'load', None), ('langchain', 'load', None), ('langchain', 'JSONLoader', 'load'), (None, 'loads', None)]
# [Signatures] No import found for load
# [Signatures] No import found for loads
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpzs7zckmh.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpzs7zckmh.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmpzs7zckmh.py:39: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] Found 3 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpbjougclb.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpbjougclb.py:39: error: Unexpected keyword argument "index" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:46: error: Missing positional arguments "file_path", "jq_schema" in call to "JSONLoader"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:46: error: Argument 2 to "DirectoryLoader" has incompatible type "JSONLoader"; expected "str"  [arg-type]
# [Mypy] /tmp/tmpbjougclb.py:49: error: Too many positional arguments for "GPT4AllEmbeddings"  [misc]
# [Mypy] /tmp/tmpbjougclb.py:59: error: Unexpected keyword argument "index" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:59: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:66: error: Missing positional arguments "file_path", "jq_schema" in call to "JSONLoader"  [call-arg]
# [Mypy] /tmp/tmpbjougclb.py:66: error: Argument 2 to "DirectoryLoader" has incompatible type "JSONLoader"; expected "str"  [arg-type]
# [Mypy] /tmp/tmpbjougclb.py:69: error: Too many positional arguments for "GPT4AllEmbeddings"  [misc]
# [Mypy] Found 11 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: DirectoryLoader
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: DirectoryLoader
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'DirectoryLoader', None), ('langchain', 'GPT4AllEmbeddings', None), ('langchain', 'ElasticsearchStore', None), ('langchain', 'DirectoryLoader', None), ('langchain', 'GPT4AllEmbeddings', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f80120c6ed0>), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f80120c6ed0>), `Elasticsearch` vector store.
# [Signatures] GPT4AllEmbeddings: (*, client: Any = None) -> None, GPT4All embedding models.
# [Signatures] DirectoryLoader: (path: str, glob: str = '**/[!.]*', silent_errors: bool = False, load_hidden: bool = False, loader_cls: Union[Type[langchain.document_loaders.unstructured.UnstructuredFileLoader], Type[langchain.document_loaders.text.TextLoader], Type[langchain.document_loaders.html_bs.BSHTMLLoader]] = <class 'langchain.document_loaders.unstructured.UnstructuredFileLoader'>, loader_kwargs: Optional[dict] = None, recursive: bool = False, show_progress: bool = False, use_multithreading: bool = False, max_concurrency: int = 4, *, sample_size: int = 0, randomize_sample: bool = False, sample_seed: Optional[int] = None), Load from a directory.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Signatures] Got signatures and documentations:
# [Signatures] JSONLoader.load: (self) -> List[langchain_core.documents.base.Document], Load and return documents from the JSON file.
# [Signatures] OllamaEmbeddings: (*, base_url: str = 'http://localhost:11434', model: str = 'llama2', embed_instruction: str = 'passage: ', query_instruction: str = 'query: ', mirostat: Optional[int] = None, mirostat_eta: Optional[float] = None, mirostat_tau: Optional[float] = None, num_ctx: Optional[int] = None, num_gpu: Optional[int] = None, num_thread: Optional[int] = None, repeat_last_n: Optional[int] = None, repeat_penalty: Optional[float] = None, temperature: Optional[float] = None, stop: Optional[List[str]] = None, tfs_z: Optional[float] = None, top_k: Optional[int] = None, top_p: Optional[int] = None, show_progress: bool = False, model_kwargs: Optional[dict] = None) -> None, Ollama locally runs large language models.
# [Signatures] GPT4AllEmbeddings: (*, client: Any = None) -> None, GPT4All embedding models.
# [Signatures] RecursiveCharacterTextSplitter: (separators: 'Optional[List[str]]' = None, keep_separator: 'bool' = True, is_separator_regex: 'bool' = False, **kwargs: 'Any') -> 'None', Splitting text by recursively look at characters.
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f80120c6ed0>), `Elasticsearch` vector store.
# [Signatures] CallbackManager: (handlers: 'List[BaseCallbackHandler]', inheritable_handlers: 'Optional[List[BaseCallbackHandler]]' = None, parent_run_id: 'Optional[UUID]' = None, *, tags: 'Optional[List[str]]' = None, inheritable_tags: 'Optional[List[str]]' = None, metadata: 'Optional[Dict[str, Any]]' = None, inheritable_metadata: 'Optional[Dict[str, Any]]' = None) -> 'None', Callback manager that handles callbacks from LangChain.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 3 conversations:
# [LLMcoder] False 4.42   ['R', 0]
# [LLMcoder] False -5.58  ['R', 1]
# [LLMcoder] False -10.58 ['R', 2]
# [LLMcoder] Starting feedback loop...
# [LLMcoder] Starting feedback iteration 1...
# [LLMcoder] Choosing conversation R-0 with score 4.42
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp90cx54wg.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp90cx54wg.py:39: error: Name "ollama" is not defined  [name-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp6ltr4_n4.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp6ltr4_n4.py:39: error: Name "ollama" is not defined  [name-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpv03bg81y.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpv03bg81y.py:39: error: Name "ollama" is not defined  [name-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 5 conversations:
# [LLMcoder] False 6.42   ['R', 0, 0]
# [LLMcoder] False 6.42   ['R', 0, 1]
# [LLMcoder] False 6.42   ['R', 0, 2]
# [LLMcoder] False -5.58  ['R', 1]
# [LLMcoder] False -10.58 ['R', 2]
# [LLMcoder] Starting feedback iteration 2...
# [LLMcoder] Choosing conversation R-0-0 with score 6.42
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp1nzstjt1.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpsc2xirhp.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmppula4alo.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 7 conversations:
# [LLMcoder] True  7.42   ['R', 0, 0, 0]
# [LLMcoder] True  7.42   ['R', 0, 0, 1]
# [LLMcoder] True  7.42   ['R', 0, 0, 2]
# [LLMcoder] False 6.42   ['R', 0, 1]
# [LLMcoder] False 6.42   ['R', 0, 2]
# [LLMcoder] False -5.58  ['R', 1]
# [LLMcoder] False -10.58 ['R', 2]
# [LLMcoder] Code is correct. Stopping early...

# %%
print(completion)
# Out:
# ElasticsearchStore("eurlex-langchain", embedding=None, es_connection=es)
