# %%
from llmcoder import LLMCoder

# %%
llmcoder = LLMCoder(
    analyzers=["mypy_analyzer_v1", "signature_analyzer_v1", "gpt_score_analyzer_v1"],
    max_iter=5,
    feedback_variant="coworker",
    n_procs=8)

# %%
initial_code = '''from langchain.document_loaders import DirectoryLoader, JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embed and store
from langchain.vectorstores.elasticsearch import ElasticsearchStore 
from langchain.embeddings import GPT4AllEmbeddings
from langchain.embeddings import OllamaEmbeddings # We can also try Ollama embeddings

from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

import os
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import time

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# pip install jq
schema = {
    'jq_schema': '.text'
}

es = get_es_connection()

REINDEX = False

# pip install gpt4all
# Needs Ubuntu > 22.04 because of glibc

if REINDEX:
    # Clear the index
    es.indices.delete(index="eurlex-langchain", ignore=[400, 404])

    start_time = time.time()
    vectorstore = '''

# %%
completion = llmcoder.complete(initial_code, n=4)
# Out:
# [LLMcoder] Creating first completions...
# [LLMcoder] Choosing conversation  with score 0
# [LLMcoder] There are no analyzer results
# [LLMcoder] Analyzing 4 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp7b5wfi43.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp7b5wfi43.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmp7b5wfi43.py:39: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmp7b5wfi43.py:48: error: "RecursiveCharacterTextSplitter" has no attribute "split"  [attr-defined]
# [Mypy] /tmp/tmp7b5wfi43.py:59: error: "ElasticsearchStore" has no attribute "add"  [attr-defined]
# [Mypy] /tmp/tmp7b5wfi43.py:60: error: "ElasticsearchStore" has no attribute "save"  [attr-defined]
# [Mypy] /tmp/tmp7b5wfi43.py:61: error: "ElasticsearchStore" has no attribute "commit"  [attr-defined]
# [Mypy] /tmp/tmp7b5wfi43.py:63: error: "ElasticsearchStore" has no attribute "close"  [attr-defined]
# [Mypy] Found 8 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: RecursiveCharacterTextSplitter
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'RecursiveCharacterTextSplitter', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpoi9gn8k3.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpoi9gn8k3.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpoi9gn8k3.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmpoi9gn8k3.py:39: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmpoi9gn8k3.py:40: error: "ElasticsearchStore" has no attribute "create_index"  [attr-defined]
# [Mypy] /tmp/tmpoi9gn8k3.py:41: error: "ElasticsearchStore" has no attribute "create_embedding_index"  [attr-defined]
# [Mypy] /tmp/tmpoi9gn8k3.py:42: error: "ElasticsearchStore" has no attribute "create_embeddings"; maybe "add_embeddings"?  [attr-defined]
# [Mypy] Found 7 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp2fxzg4nx.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp2fxzg4nx.py:39: error: Unexpected keyword argument "index" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp2fxzg4nx.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp2fxzg4nx.py:39: error: Unexpected keyword argument "batch_size" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp2fxzg4nx.py:47: error: Missing positional argument "handlers" in call to "CallbackManager"  [call-arg]
# [Mypy] Found 5 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [Signatures] RecursiveCharacterTextSplitter: (separators: 'Optional[List[str]]' = None, keep_separator: 'bool' = True, is_separator_regex: 'bool' = False, **kwargs: 'Any') -> 'None', Splitting text by recursively look at characters.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp0qw2_vyh.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp0qw2_vyh.py:39: error: Unexpected keyword argument "index" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp0qw2_vyh.py:40: error: "ElasticsearchStore" has no attribute "clear"  [attr-defined]
# [Mypy] Found 3 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 4 conversations with scores -4.968565207460511, -0.4155855021346815, -2.4155855021346815, 1.5844144978653185
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] Starting feedback loop...
# [LLMcoder] Starting feedback iteration 1...
# [LLMcoder] Choosing conversation  with score 4.97
# [LLMcoder] Analyzing 4 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmps0d0anw2.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpc0eger_6.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpc0eger_6.py:40: error: "ElasticsearchStore" has no attribute "clear_index"  [attr-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpwy8myzy6.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpwy8myzy6.py:40: error: "ElasticsearchStore" has no attribute "clear_index"  [attr-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpo69w9ctm.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpo69w9ctm.py:40: error: "ElasticsearchStore" has no attribute "clear_index"  [attr-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f228c76d490>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 7 conversations with scores -7.968565207460511, -5.4155855021346815, -5.4155855021346815, -0.4155855021346815, -2.4155855021346815, 1.5844144978653185, -5.4155855021346815
# [LLMcoder] 1 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] 0 / 1 analyzers passed
# [LLMcoder] Code is correct. Stopping early...

# %%
print(completion)
# Out:
# ElasticsearchStore("eurlex-langchain", es_connection=es)
