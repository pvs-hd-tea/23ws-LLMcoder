# %%
from llmcoder import LLMCoder

# %%
llmcoder = LLMCoder(
    analyzers=["mypy_analyzer_v1", "signature_analyzer_v1", "gpt_score_analyzer_v1"],
    max_iter=5,
    feedback_variant="coworker",
    n_procs=4)

# %%
initial_code = '''from langchain.document_loaders import DirectoryLoader, JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embed and store
from langchain.vectorstores.elasticsearch import ElasticsearchStore 
from langchain.embeddings import GPT4AllEmbeddings
from langchain.embeddings import OllamaEmbeddings # We can also try Ollama embeddings

from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

import os
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import time

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# pip install jq
schema = {
    'jq_schema': '.text'
}

es = get_es_connection()

REINDEX = False

# pip install gpt4all
# Needs Ubuntu > 22.04 because of glibc

if REINDEX:
    # Clear the index
    es.indices.delete(index="eurlex-langchain", ignore=[400, 404])

    start_time = time.time()
    vectorstore = '''

# %%
completion = llmcoder.complete(initial_code, n=3)
# Out:
# [LLMcoder] Creating first completions...
# [LLMcoder] Choosing conversation R with score 0
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp6uhp2n9b.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp6uhp2n9b.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmp6uhp2n9b.py:41: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmp6uhp2n9b.py:44: error: Missing named argument "client" for "GPT4AllEmbeddings"  [call-arg]
# [Mypy] /tmp/tmp6uhp2n9b.py:44: error: Argument 5 to "ElasticsearchStore" has incompatible type "GPT4AllEmbeddings"; expected "str | None"  [arg-type]
# [Mypy] Found 5 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'GPT4AllEmbeddings', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpc6wcq5x3.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpc6wcq5x3.py:39: error: Unexpected keyword argument "index" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpc6wcq5x3.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmpc6wcq5x3.py:40: error: "ElasticsearchStore" has no attribute "init_store"  [attr-defined]
# [Mypy] Found 4 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp884mlxbh.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp884mlxbh.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmp884mlxbh.py:40: error: Too many positional arguments for "GPT4AllEmbeddings"  [misc]
# [Mypy] /tmp/tmp884mlxbh.py:42: error: Missing positional argument "handlers" in call to "CallbackManager"  [call-arg]
# [Mypy] /tmp/tmp884mlxbh.py:43: error: "CallbackManager" has no attribute "register"  [attr-defined]
# [Mypy] /tmp/tmp884mlxbh.py:47: error: "DirectoryLoader" has no attribute "register"  [attr-defined]
# [Mypy] /tmp/tmp884mlxbh.py:49: error: "ElasticsearchStore" has no attribute "register"  [attr-defined]
# [Mypy] Found 7 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] Found problematic function or class: CallbackManager
# [Signatures] Found problematic function or class: DirectoryLoader
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'GPT4AllEmbeddings', None), ('langchain', 'CallbackManager', None), ('langchain', 'DirectoryLoader', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f8544a7fa10>), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Signatures] Got signatures and documentations:
# [Signatures] GPT4AllEmbeddings: (*, client: Any = None) -> None, GPT4All embedding models.
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f8544a7fa10>), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Signatures] Got signatures and documentations:
# [Signatures] GPT4AllEmbeddings: (*, client: Any = None) -> None, GPT4All embedding models.
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f8544a7fa10>), `Elasticsearch` vector store.
# [Signatures] DirectoryLoader: (path: str, glob: str = '**/[!.]*', silent_errors: bool = False, load_hidden: bool = False, loader_cls: Union[Type[langchain.document_loaders.unstructured.UnstructuredFileLoader], Type[langchain.document_loaders.text.TextLoader], Type[langchain.document_loaders.html_bs.BSHTMLLoader]] = <class 'langchain.document_loaders.unstructured.UnstructuredFileLoader'>, loader_kwargs: Optional[dict] = None, recursive: bool = False, show_progress: bool = False, use_multithreading: bool = False, max_concurrency: int = 4, *, sample_size: int = 0, randomize_sample: bool = False, sample_seed: Optional[int] = None), Load from a directory.
# [Signatures] CallbackManager: (handlers: 'List[BaseCallbackHandler]', inheritable_handlers: 'Optional[List[BaseCallbackHandler]]' = None, parent_run_id: 'Optional[UUID]' = None, *, tags: 'Optional[List[str]]' = None, inheritable_tags: 'Optional[List[str]]' = None, metadata: 'Optional[Dict[str, Any]]' = None, inheritable_metadata: 'Optional[Dict[str, Any]]' = None) -> 'None', Callback manager that handles callbacks from LangChain.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 3 conversations:
# [LLMcoder] Passing   Score     Prob      Path
# [LLMcoder] False     4.23      1.0       ['R', 0]
# [LLMcoder] False     1.42      0.0       ['R', 1]
# [LLMcoder] False     -2.25     0.0       ['R', 2]
# [LLMcoder] Starting feedback loop...
# [LLMcoder] Starting feedback iteration 1...
# [LLMcoder] Choosing conversation R-0 with score 4.23
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpek2bqrgd.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpw1m17n16.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpw1m17n16.py:40: error: "ElasticsearchStore" has no attribute "init_store"  [attr-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f8544a7fa10>), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmp27klflcd.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmp27klflcd.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmp27klflcd.py:39: error: Missing named argument "client" for "GPT4AllEmbeddings"  [call-arg]
# [Mypy] /tmp/tmp27klflcd.py:40: error: "ElasticsearchStore" has no attribute "init_store"  [attr-defined]
# [Mypy] Found 4 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: GPT4AllEmbeddings
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'GPT4AllEmbeddings', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] GPT4AllEmbeddings: (*, client: Any = None) -> None, GPT4All embedding models.
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7f8544a7fa10>), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 5 conversations:
# [LLMcoder] Passing   Score     Prob      Path
# [LLMcoder] True      7.42      1.0       ['R', 0, 2]
# [LLMcoder] False     5.97      0.0       ['R', 0, 1]
# [LLMcoder] False     2.99      0.0       ['R', 0, 0]
# [LLMcoder] False     1.42      0.0       ['R', 1]
# [LLMcoder] False     -2.25     0.0       ['R', 2]
# [LLMcoder] Code is correct. Stopping early...

# %%
print(completion)
# Out:
# ElasticsearchStore("eurlex-langchain", es_connection=es)
#     print("Time to create store:", time.time() - start_time)
#
#     start_time = time.time()
#     ollama = Ollama(vectorstore, es)
#     ollama.init_index(schema)
#     print("Time to create index:", time.time() - start_time)
