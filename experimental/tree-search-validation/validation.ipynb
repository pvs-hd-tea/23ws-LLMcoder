# %%
from llmcoder import LLMCoder

# %%
llmcoder = LLMCoder(
    analyzers=["mypy_analyzer_v1", "signature_analyzer_v1", "gpt_score_analyzer_v1"],
    max_iter=5,
    feedback_variant="coworker",
    n_procs=4,
    backtracking=True)

# %%
initial_code = '''from langchain.document_loaders import DirectoryLoader, JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embed and store
from langchain.vectorstores.elasticsearch import ElasticsearchStore 
from langchain.embeddings import GPT4AllEmbeddings
from langchain.embeddings import OllamaEmbeddings # We can also try Ollama embeddings

from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

import os
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import time

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# pip install jq
schema = {
    'jq_schema': '.text'
}

es = get_es_connection()

REINDEX = False

# pip install gpt4all
# Needs Ubuntu > 22.04 because of glibc

if REINDEX:
    # Clear the index
    es.indices.delete(index="eurlex-langchain", ignore=[400, 404])

    start_time = time.time()
    vectorstore = '''

# %%
completion = llmcoder.complete(initial_code, n=3)
# Out:
# [LLMcoder] Creating first completions...
# [LLMcoder] Choosing conversation R with score 0
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmplnk4g6wn.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmplnk4g6wn.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmplnk4g6wn.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmplnk4g6wn.py:40: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmplnk4g6wn.py:40: error: Argument 4 to "ElasticsearchStore" has incompatible type "int"; expected "str | None"  [arg-type]
# [Mypy] /tmp/tmplnk4g6wn.py:40: error: Argument 5 to "ElasticsearchStore" has incompatible type "int"; expected "str | None"  [arg-type]
# [Mypy] Found 6 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmprv0fg4bi.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmprv0fg4bi.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmprv0fg4bi.py:39: error: Argument 2 to "ElasticsearchStore" has incompatible type "str"; expected "Embeddings | None"  [arg-type]
# [Mypy] /tmp/tmprv0fg4bi.py:50: error: "ElasticsearchStore" has no attribute "embed_and_store"  [attr-defined]
# [Mypy] Found 4 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7fe7974f8990>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7fe7974f8990>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmporqwqaci.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmporqwqaci.py:39: error: Unexpected keyword argument "schema" for "ElasticsearchStore"  [call-arg]
# [Mypy] /tmp/tmporqwqaci.py:39: error: Too many positional arguments for "ElasticsearchStore"  [misc]
# [Mypy] /tmp/tmporqwqaci.py:41: error: Argument 1 to "RecursiveCharacterTextSplitter" has incompatible type "ElasticsearchStore"; expected "list[str] | None"  [arg-type]
# [Mypy] /tmp/tmporqwqaci.py:43: error: Need type annotation for "doc"  [var-annotated]
# [Mypy] /tmp/tmporqwqaci.py:43: error: Argument 1 to "enumerate" has incompatible type "RecursiveCharacterTextSplitter"; expected "Iterable[Never]"  [arg-type]
# [Mypy] /tmp/tmporqwqaci.py:50: error: "ElasticsearchStore" has no attribute "index_all"  [attr-defined]
# [Mypy] Found 7 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] Found problematic function or class: RecursiveCharacterTextSplitter
# [Signatures] Found problematic function or class: doc
# [Signatures] Found problematic function or class: enumerate
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None), ('langchain', 'RecursiveCharacterTextSplitter', None), (None, 'enumerate', None)]
# [Signatures] No import found for enumerate
# [Signatures] Got signatures and documentations:
# [Signatures] RecursiveCharacterTextSplitter: (separators: 'Optional[List[str]]' = None, keep_separator: 'bool' = True, is_separator_regex: 'bool' = False, **kwargs: 'Any') -> 'None', Splitting text by recursively look at characters.
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7fe7974f8990>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 3 conversations:
# [LLMcoder] Passing   Score     Prob      Path
# [LLMcoder] False     3.42      1.0       ['R', 0]
# [LLMcoder] False     1.42      0.0       ['R', 1]
# [LLMcoder] False     -0.25     0.0       ['R', 2]
# [LLMcoder] Starting feedback loop...
# [LLMcoder] Starting feedback iteration 1...
# [LLMcoder] Choosing conversation R-0 with score 3.42
# [LLMcoder] Analyzing 3 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpoa05oxot.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpye51ofwf.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpye51ofwf.py:48: error: "ElasticsearchStore" has no attribute "embed_and_store"  [attr-defined]
# [Mypy] Found 2 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] Found problematic function or class: ElasticsearchStore
# [Signatures] function_calls=[('langchain', 'ElasticsearchStore', None)]
# [Signatures] Got signatures and documentations:
# [Signatures] ElasticsearchStore: (index_name: str, *, embedding: Optional[langchain_core.embeddings.Embeddings] = None, es_connection: Optional[ForwardRef('Elasticsearch')] = None, es_url: Optional[str] = None, es_cloud_id: Optional[str] = None, es_user: Optional[str] = None, es_api_key: Optional[str] = None, es_password: Optional[str] = None, vector_query_field: str = 'vector', query_field: str = 'text', distance_strategy: Optional[Literal[<DistanceStrategy.COSINE: 'COSINE'>, <DistanceStrategy.DOT_PRODUCT: 'DOT_PRODUCT'>, <DistanceStrategy.EUCLIDEAN_DISTANCE: 'EUCLIDEAN_DISTANCE'>]] = None, strategy: langchain_community.vectorstores.elasticsearch.BaseRetrievalStrategy = <langchain_community.vectorstores.elasticsearch.ApproxRetrievalStrategy object at 0x7fe7974f8990>, es_params: Optional[Dict[str, Any]] = None), `Elasticsearch` vector store.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpjv3uooyz.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] Found 1 error in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Have 5 conversations:
# [LLMcoder] Passing   Score     Prob      Path
# [LLMcoder] True      7.97      1.0       ['R', 0, 1]
# [LLMcoder] True      7.42      0.0       ['R', 0, 2]
# [LLMcoder] False     5.73      0.0       ['R', 0, 0]
# [LLMcoder] False     1.42      0.0       ['R', 1]
# [LLMcoder] False     -0.25     0.0       ['R', 2]
# [LLMcoder] Code is correct. Stopping early...

# %%
print(completion)
# Out:
# ElasticsearchStore("eurlex-langchain", embedding=GPT4AllEmbeddings(device=device))
