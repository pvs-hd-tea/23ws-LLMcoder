# %% [markdown]
# # Set Up and Refactor to use dependency

# %% [markdown]
# We makee use of OpenAIPlayground to contrast the utility of different models.

# %% [markdown]
# ![image.png](attachment:image.png)
