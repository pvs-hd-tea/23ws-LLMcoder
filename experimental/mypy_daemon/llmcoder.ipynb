# %%
from llmcoder import LLMCoder

# %%
# Stop the daemon process
import subprocess
subprocess.run(["dmypy", "stop"])
# Out:
# No status file found
# CompletedProcess(args=['dmypy', 'stop'], returncode=2)

# %%
# Clear the mypy cache
import shutil
shutil.rmtree(".mypy_cache", ignore_errors=True)

# %%
llmcoder = LLMCoder(
    analyzers=["mypy_analyzer_v1", "signature_analyzer_v1", "gpt_score_analyzer_v1"],
    max_iter=3,
    feedback_variant="coworker",
    n_procs=16)

# %%
code = """from langchain.document_loaders import DirectoryLoader, JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embed and store
from langchain.vectorstores.elasticsearch import ElasticsearchStore 
from langchain.embeddings import GPT4AllEmbeddings
from langchain.embeddings import OllamaEmbeddings # We can also try Ollama embeddings

from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

import os
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import time

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# pip install jq
schema = {
    'jq_schema': '.text'
}

es = get_es_connection()

my_array = np.array([1, 2, 3, 4, 5])

REINDEX = False

# pip install gpt4all
# Needs Ubuntu > 22.04 because of glibc

if REINDEX:
    # Clear the index
    es.indices.delete(index="eurlex-langchain", ignore=[400, 404])

    start_time = time.time()
    vectorstore = """

# %%
llmcoder.setup(code)
# Out:
# [Mypy] Creating cache...
# [Mypy] No missing stubs found.

# %%
result = llmcoder.complete(code, n=16)
# Out:
# [LLMcoder] Creating first completion...
# [LLMcoder] Analyzing 16 completions...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [LLMcoder] Analyzing code in coworker mode...
# [LLMcoder] Running mypy_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Mypy] No missing stubs found.
# [Mypy] /tmp/tmpqn15ml_k.py:1: error: Cannot find implementation or library stub for module named "langchain.document_loaders"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:2: error: Cannot find implementation or library stub for module named "langchain.text_splitter"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: error: Cannot find implementation or library stub for module named "langchain.vectorstores.elasticsearch"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:5: note: See https://mypy.readthedocs.io/en/stable/running_mypy.html#missing-imports
# [Mypy] /tmp/tmpqn15ml_k.py:6: error: Cannot find implementation or library stub for module named "langchain.embeddings"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:9: error: Cannot find implementation or library stub for module named "langchain.llms"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:10: error: Cannot find implementation or library stub for module named "langchain.callbacks.manager"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:11: error: Cannot find implementation or library stub for module named "langchain.callbacks.streaming_stdout"  [import-not-found]
# [Mypy] /tmp/tmpqn15ml_k.py:27: error: Name "get_es_connection" is not defined  [name-defined]
# [Mypy] /tmp/tmpqn15ml_k.py:29: error: Name "np" is not defined  [name-defined]
# [Mypy] Found 9 errors in 1 file (checked 1 source file)
# [LLMcoder] Running signature_analyzer_v1...
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [Signatures] Using context from previous analyzers: ['mypy_analyzer_v1']
# [Signatures] No problematic functions or classes found in the context.
# [LLMcoder] Running gpt_score_analyzer_v1...
# [LLMcoder] Running gpt_score_analyzer_v1...
# [Scoring] Choosing message 9 with score 8.231010797211804
# [LLMcoder] 1 / 1 analyzers passed

# %%
print(result)
# Out:
# ElasticsearchStore(hosts="http://localhost:9200", index_name="eurlex-langchain", schema=schema, device=device)
#     print(f"Vectorstore initalization: {time.time() - start_time} seconds.")
#
#     # Load the documents
#     start_time = time.time()
#     directory_loader = DirectoryLoader(directories=["/mnt/data/eurlex_raw"], extensions=[".json"], recursive=True)
#     documents = directory_loader.load()
#     print(f"Document load: {time.time() - start_time} seconds.")
#
#     # Load the embeddings
#     start_time = time.time()
#     gpt4all = GPT4AllEmbeddings(device=device)
#     ollama = OllamaEmbeddings(device=device)
#     print(f"Embeddings load: {time.time() - start_time} seconds.")
#
#     # Split the text
#     start_time = time.time()
#     text_splitter = RecursiveCharacterTextSplitter(max_characters=4096)
#     print(f"Text splitter initalization: {time.time() - start_time} seconds.")
